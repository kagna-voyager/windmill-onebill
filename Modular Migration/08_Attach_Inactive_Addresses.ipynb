# %% [markdown]
# # 06 — Attach Inactive Addresses
#
# **Run this AFTER `06_Create_Addresses.ipynb` (the active one) has finished.**
#
# Inactive subscriptions don't get a new address — each one is attached to
# whichever address is *currently* the target account's default service
# address (`defaultShipping = true`), via `find_default_shipping_address_id()`.
#
# This only works correctly once every active subscription's address has
# already been created, because each newly-created address supersedes the
# previous default (see `add_address_to_account` in `onebill_common.py`) — the
# "final" default for an account isn't settled until its last active address
# exists. Running this before or during the active pass could pick up a
# default that's about to be replaced.
#
# Accounts with no active subscriptions at all (nothing to have established a
# default) will fail here — there's nothing to attach to.

# %% [markdown]
# ## 1. Setup

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd()))

from onebill_common import *  # noqa: F401,F403
from concurrent.futures import ThreadPoolExecutor, as_completed

logger = get_logger("attach_inactive_addresses")

df_subscriptions = try_load_df("subscriptions_inactive_resolved", dtype=SUBSCRIPTIONS_RESOLVED_DTYPES)
if df_subscriptions is None or df_subscriptions.empty:
    logger.warning("No 'subscriptions_inactive_resolved' file found (or it's empty) — run 05_Fetch_Inactive_Subscriptions.ipynb first, or there simply were no inactive subscriptions.")
    df_subscriptions = pd.DataFrame()
else:
    logger.info(f"Loaded {len(df_subscriptions):,} inactive subscriptions")
# Out:
# python-dotenv could not parse statement starting at line 1
# python-dotenv could not parse statement starting at line 5
# python-dotenv could not parse statement starting at line 12
# python-dotenv could not parse statement starting at line 17
# python-dotenv could not parse statement starting at line 23
# python-dotenv could not parse statement starting at line 29
# 2026-07-24 15:19:30,520 [INFO] Loaded 59 inactive subscriptions

# %% [markdown]
# ## 2. Per-subscription default-address lookup

# %%
def attach_to_default_address(session: requests.Session, row: dict) -> dict:
    subscription_id = row["SubscriptionUSN"]
    account_number  = row["TargetAccountNumber"]

    result = {
        "SubscriptionUSN":     subscription_id,
        "TargetAccountNumber": account_number,
        "status":              "failed",
        "ship_add_id":         None,
        "error":               None,
    }

    status, address_id, error = find_default_shipping_address_id(session, account_number)
    if status == "found":
        result["status"] = "reused_default"
        result["ship_add_id"] = address_id
        logger.info(f"[OK] subscription {subscription_id} (inactive) -> {account_number} reusing default address id={address_id}")
    elif status == "not_found":
        result["error"] = "account has no address with defaultShipping=true to reuse — has its active pass run yet?"
        logger.error(f"[FAIL] subscription {subscription_id} (inactive) — {result['error']}")
    else:
        result["error"] = error
        logger.error(f"[FAIL] subscription {subscription_id} (inactive) — {error}")

    return result

# %% [markdown]
# ## 3. Run (parallel driver)

# %%
def attach_all_inactive(df: pd.DataFrame, max_workers: int = MAX_WORKERS) -> pd.DataFrame:
    session = new_session(max_workers=max_workers)
    rows = df.to_dict("records")
    total = len(rows)
    results = []
    logger.info(f"Attaching {total:,} inactive subscriptions to their account's default address, {max_workers} workers...")
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(attach_to_default_address, session, row): row["SubscriptionUSN"] for row in rows}
        for i, future in enumerate(as_completed(futures), start=1):
            results.append(future.result())
            if i % 50 == 0 or i == total:
                ok = sum(1 for r in results if r["status"] == "reused_default")
                logger.info(f"Progress: {i}/{total} — {ok} attached so far")
    return pd.DataFrame(results)


if df_subscriptions.empty:
    df_address_results_inactive = pd.DataFrame(columns=["SubscriptionUSN", "TargetAccountNumber", "status", "ship_add_id", "error"])
else:
    df_address_results_inactive = attach_all_inactive(df_subscriptions)

df_address_results_inactive.head(20)
# Out:
# 2026-07-24 15:19:31,833 [INFO] Attaching 59 inactive subscriptions to their account's default address, 10 workers...
# 2026-07-24 15:19:53,608 [INFO] [OK] subscription V113063259 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:19:53,759 [INFO] [OK] subscription V113064380 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:19:53,827 [INFO] [OK] subscription V113062897 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:19:53,834 [INFO] [OK] subscription V113062905 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:19:53,867 [INFO] [OK] subscription V113064372 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:19:53,911 [INFO] [OK] subscription V113063267 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:19:54,011 [INFO] [OK] subscription V113064349 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:19:54,045 [INFO] [OK] subscription V113064125 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:19:54,127 [INFO] [OK] subscription V113062913 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:19:54,150 [INFO] [OK] subscription V113063077 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:11,950 [INFO] [OK] subscription V113064489 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:13,004 [INFO] [OK] subscription V113064521 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:13,295 [INFO] [OK] subscription V113066419 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:13,414 [INFO] [OK] subscription V113065130 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:13,574 [INFO] [OK] subscription V113066468 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:20:13,591 [INFO] [OK] subscription V113066534 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:20:13,608 [INFO] [OK] subscription V113066278 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:20:13,619 [INFO] [OK] subscription V113066781 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:13,697 [INFO] [OK] subscription V113068076 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:13,713 [INFO] [OK] subscription V113068019 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:22,941 [INFO] [OK] subscription V113068274 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:30,728 [INFO] [OK] subscription V113068282 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:31,895 [INFO] [OK] subscription V113068241 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:32,390 [INFO] [OK] subscription V113068266 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:32,646 [INFO] [OK] subscription V113068340 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:32,672 [INFO] [OK] subscription V113068316 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:33,714 [INFO] [OK] subscription V113068811 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:33,730 [INFO] [OK] subscription V113068332 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:33,830 [INFO] [OK] subscription V113068837 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:33,854 [INFO] [OK] subscription V113068688 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:36,008 [INFO] [OK] subscription V113069082 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:44,187 [INFO] [OK] subscription V113069090 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:47,538 [INFO] [OK] subscription V113070767 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:48,839 [INFO] [OK] subscription V113073092 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:49,269 [INFO] [OK] subscription V113073605 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:49,391 [INFO] [OK] subscription V113073613 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:52,307 [INFO] [OK] subscription V113079214 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:20:53,656 [INFO] [OK] subscription V113076327 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:53,740 [INFO] [OK] subscription V113079164 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:20:53,967 [INFO] [OK] subscription V113077895 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:20:53,986 [INFO] [OK] subscription V113076459 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:21:00,837 [INFO] [OK] subscription V113079305 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:05,390 [INFO] [OK] subscription V113079313 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:07,269 [INFO] [OK] subscription V113079354 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:08,002 [INFO] [OK] subscription V113079578 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:08,015 [INFO] [OK] subscription V113079594 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:10,641 [INFO] [OK] subscription V113080535 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:12,567 [INFO] [OK] subscription V113080584 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:12,687 [INFO] [OK] subscription V113080626 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:12,830 [INFO] [OK] subscription V113080683 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:12,832 [INFO] Progress: 50/59 — 50 attached so far
# 2026-07-24 15:21:12,990 [INFO] [OK] subscription V113084529 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:17,641 [INFO] [OK] subscription V113084545 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:21,233 [INFO] [OK] subscription V113084552 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:22,548 [INFO] [OK] subscription V113084560 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:22,836 [INFO] [OK] subscription V113084578 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:22,992 [INFO] [OK] subscription V113085443 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:23,719 [INFO] [OK] subscription V113085690 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:23,933 [INFO] [OK] subscription V113086003 (inactive) -> 999656921_fullbatch4 reusing default address id=141989
# 2026-07-24 15:21:23,991 [INFO] [OK] subscription V113092746 (inactive) -> 99965692_fullbatch4 reusing default address id=141981
# 2026-07-24 15:21:23,992 [INFO] Progress: 59/59 — 59 attached so far
#    SubscriptionUSN   TargetAccountNumber          status ship_add_id error
# 0       V113063259   99965692_fullbatch4  reused_default      141981  None
# 1       V113064380   99965692_fullbatch4  reused_default      141981  None
# 2       V113062897  999656921_fullbatch4  reused_default      141989  None
# 3       V113062905   99965692_fullbatch4  reused_default      141981  None
# 4       V113064372   99965692_fullbatch4  reused_default      141981  None
# 5       V113063267   99965692_fullbatch4  reused_default      141981  None
# 6       V113064349   99965692_fullbatch4  reused_default      141981  None
# 7       V113064125   99965692_fullbatch4  reused_default      141981  None
# 8       V113062913   99965692_fullbatch4  reused_default      141981  None
# 9       V113063077   99965692_fullbatch4  reused_default      141981  None
# 10      V113064489   99965692_fullbatch4  reused_default      141981  None
# 11      V113064521   99965692_fullbatch4  reused_default      141981  None
# 12      V113066419   99965692_fullbatch4  reused_default      141981  None
# 13      V113065130   99965692_fullbatch4  reused_default      141981  None
# 14      V113066468  999656921_fullbatch4  reused_default      141989  None
# 15      V113066534  999656921_fullbatch4  reused_default      141989  None
# 16      V113066278  999656921_fullbatch4  reused_default      141989  None
# 17      V113066781   99965692_fullbatch4  reused_default      141981  None
# 18      V113068076   99965692_fullbatch4  reused_default      141981  None
# 19      V113068019   99965692_fullbatch4  reused_default      141981  None

# %% [markdown]
# ## 4. Failures

# %%
not_attached = df_address_results_inactive[df_address_results_inactive["status"] != "reused_default"]
print(f"{len(not_attached):,} / {len(df_address_results_inactive):,} inactive subscriptions not attached")
not_attached
# Out:
# 0 / 59 inactive subscriptions not attached
# Empty DataFrame
# Columns: [SubscriptionUSN, TargetAccountNumber, status, ship_add_id, error]
# Index: []

# %% [markdown]
# ## 5. Save

# %%
save_df("address_results_inactive", df_address_results_inactive)
# Out:
# Saved 59 rows -> migration_data\06_address_results_inactive.csv
