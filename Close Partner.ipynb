# %%
# pip install requests
import requests, pandas as pd

baseUrl = 'https://sandbox-sg.onebillsoftware.com'
deletepartnerEndpoint = '/rest/PartnerService/v1/partners/deletePartner/'
partnerEndpoint = '/rest/PartnerService/v1/partners/'
accessTokenURL = f'{baseUrl}/oauth/token'

clientID = 'voyagersbx'
clientSecret = '13ad8f7edb3663a64cf1ce57a1860b68591669d2762a2de09c8dc78bdc03ed81'
username = 'api.usersbx'
password = '592bc33d78294f301df7b98752a4b7f0e6cdaab21555551f9a77377a0938976b'

# %%
def get_AccessToken():
    tokenData = {
        'grant_type': 'password',
        'client_id': clientID,
        'client_secret': clientSecret,
        'username': username,
        'password': password
    }

    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.post(accessTokenURL, data=tokenData, headers=headers)

    if response.status_code == 200:
        accessToken = response.json()
        return accessToken['access_token']
    else:
        print(f'Token Request Failed: {response.status_code} - {response.text}')
        return None

# %%
import requests
import json

url = f'{baseUrl}{partnerEndpoint}/2606/resume'

payload={}
headers = {
  'Content-Type': 'application/json',
  'Authorization': f'Bearer {token}'
}

response = requests.request("DELETE", url, headers=headers, data=payload)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head lang="en">
# <meta charset="UTF-8">
# <title>404 page</title>
# <link rel="stylesheet" href="../404/css/404.css">
# <!-- <link rel='stylesheet' href='http://fonts.googleapis.com/css?family=Lato:300,400,700' type='text/css'> -->
# <link rel="stylesheet" href="../font/web/fonts.css">
# </head>
#
#
# <body>
# 	<div class="Center-Container">
# 		<div class="error-img-block">
# 			<img src="../404/images/404_image.png" alt="404" />
# 		</div>
# 		<div class="error-content-block">
#
# 			<div class="not-found-block">
# 				<h5>ERROR 404!!!</h5>
# 				<p>Sorry,that page doesn't exist!</p>
# 			</div>
# 			<!-- not-found-block -->
# 			<!-- <div class="url-block">
# 				<p>
# 					Go to the <a href="https://app.onebillsoftware.com">Home page</a>
# 				</p>
# 			</div> -->
# 			<!-- url-block -->
#
# 		</div>
# 		<!-- error content block -->
#
#
#
# 	</div>
# 	<!--center-container -->
# </body>
# </html>
